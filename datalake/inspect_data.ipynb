# %%
import pandas as pd

# %%
df_datasets = pd.read_parquet("data/row_data/datasets.parquet")
print(df_datasets.columns)
# Out:
# Index(['url', 'name', 'full_name', 'homepage', 'description', 'paper',
#        'introduced_date', 'warning', 'modalities', 'tasks', 'languages',
#        'variants', 'num_papers', 'data_loaders'],
#       dtype='object')

# %%
df_datasets.iloc[0]
# Out:
# url                         https://paperswithcode.com/dataset/mnist
# name                                                           MNIST
# full_name
# homepage                           http://yann.lecun.com/exdb/mnist/
# description        The **MNIST** database (**Modified National In...
# paper              {'title': 'Gradient-based learning applied to ...
# introduced_date                                           1998-11-01
# warning                                                         None
# modalities                                                  [Images]
# tasks              [{'task': 'Image Classification', 'url': 'http...
# languages                                                  [English]
# variants           [USPS-to-MNIST, MNIST-to-USPS, Rotating MNIST,...
# num_papers                                                      6005
# data_loaders       [{'frameworks': ['tf', 'pytorch', 'jax'], 'rep...
# Name: 0, dtype: object

# %%
df_datasets.iloc[20]["tasks"]
# Out:
# array([{'task': 'Semantic Segmentation', 'url': 'https://paperswithcode.com/task/semantic-segmentation'},
#        {'task': 'Human Part Segmentation', 'url': 'https://paperswithcode.com/task/human-part-segmentation'},
#        {'task': 'Human Parsing', 'url': 'https://paperswithcode.com/task/human-parsing'},
#        {'task': 'Multi-Human Parsing', 'url': 'https://paperswithcode.com/task/multi-human-parsing'}],
#       dtype=object)

# %%
df_evaluation = pd.read_parquet("data/row_data/evaluation_tables.parquet")
print(df_evaluation.columns)
# Out:
# Index(['categories', 'datasets', 'source_link', 'synonyms', 'task', 'subtasks',
#        'description'],
#       dtype='object')

# %%
df_evaluation.iloc[1]["datasets"][0]
# Out:
# {'dataset': 'DVD ',
#  'dataset_citations': array([], dtype=object),
#  'dataset_links': array([{'title': 'Papers with Code Leaderboard URL', 'url': 'https://paperswithcode.com/sota/deblurring-on-dvd'}],
#        dtype=object),
#  'description': '',
#  'sota': {'metrics': array(['PSNR'], dtype=object),
#   'rows': array([{'code_links': array([{'title': 'linjing7/VR-Baseline', 'url': 'https://github.com/linjing7/VR-Baseline'}],
#                dtype=object), 'metrics': {'\t ACCURACY': None, ' Content Ordering': None, ' Content Selection (F1)': None, ' Human listening average results': None, ' KIN': None, ' LUO': None, ' Macro-F1': None, ' Over': None, ' Rank-1': None, ' Rank-1 (All Search)': None, ' Rank-1 (Indoor Search)': None, ' Rank-5': None, ' Runtime (s)': None, ' SSIM': None, ' box AP': None, ' mAP': None, ' mAP (All Search)': None, ' mAP (Indoor Search)': None, ' mINP': None, ' mINP (All Search)': None, ' mINP (Indoor Search)': None, '# M Params': None, '# Parameters': None, '% < 11.25': None, '% < 22.5': None, '% < 30': None, '% Dev Accuracy': None, '% Test Accuracy': None, '% Test Accuracy (Raw Data)': None, '% Train Accuracy': None, '% info': None, '% true': None, '% true (GPT-judge)': None, '(Recall@10+Recall@50)/2': None, '(Recall@5+Recall_subset@1)/2': None, '-1': None, '0..5sec': None, '0L': None, '0S': None, '1 - LPIPS': None, '1 in 10 R@1': None, '1 in 10 R@2': None, '1 in 10 R@5': None, '1 step MAE': None, '1-NNA-CD': None, '1-of-100 Accuracy': None, '1/2': None, '1/4': None, '10 Hops': None, '10 fold Cross validation': None, '10 steps MAE': None, '10 way 1~2 shot': None, '10 way 5~10 shot': None, '10%': None, '10-20% Mask PSNR': None, '10-keyword Speech Commands dataset': None, '10-stage average accuracy': None, '10°10 cm': None, '12 Steps MAE': None, '12 steps MAE': None, '12 steps MAPE': None, '12 steps RMSE': None, '14 gestures accuracy': None, '1:1 Accuracy': None, '1:3 Accuracy': None, '1x1 NLL': None, '2-Class Accuracy': None, '20%': None, '20-30% Mask PSNR': None, '3-class test accuracy': None, '3-fold Accuracy': None, '30%': None, '30-40% Mask PSNR': None, '3DIoU': None, '3DMOTA': None, '3DPCK': None, '4 Hops': None, '40%': None, '40-50% Mask PSNR': None, '5 Hops': None, '5 fold cross validation': None, '5 way 1~2 shot': None, '520': None, '6 Hops': None, '7 Hops': None, '8 Hops': None, '9 Hops': None, '9 steps MAE': None, '95-th Percentile Speed Measurement Error (km/h)': None, '99-th Percentile Speed Measurement Error (km/h)': None, '99.46%': None, '@cheek': None, '@forehead': None, '@mouth': None, '@nose': None, 'A-R@1': None, 'A-R@10': None, 'A-R@5': None, 'A-acc': None, 'A-mIoU': None, 'A1': None, 'A2': None, 'A3': None, 'A3DP': None, 'AAA': None, 'ABX-across': None, 'ABX-within': None, 'ACC': None, 'ACC@1-100Clients': None, 'ACCURACY': None, 'ADDS AUC': None, 'ADE': None, 'ADE (8/12) @K=5': None, 'ADE (in world coordinates)': None, 'ADE(0.5)': None, 'ADE(1.0)': None, 'ADE(1.5)': None, 'ADE-8/12': None, 'ADE-8/12 @K = 20': None, 'AED': None, 'AEPE (rate=3)': None, 'AEPE (rate=5)': None, 'AIOU': None, 'AKD': None, 'ALL': None, 'ALL (miss rate)': None, 'AMD': None, 'AMH': None, 'AMOTA': None, 'AMV': None, 'ANLI': None, 'ANLS': None, 'ANS-EM': None, 'ANS-F1': None, 'AOP': None, 'AP': None, 'AP (Detection)': None, 'AP 0.5': None, 'AP Easy': None, 'AP Hard': None, 'AP Medium': None, 'AP novel-LVIS base training': None, 'AP novel-Unrestricted open-vocabulary training': None, 'AP(S1)': None, 'AP(S2)': None, 'AP(l)': None, 'AP(m)': None, 'AP(s)': None, 'AP/L2': None, 'AP0.5 (Noisy)': None, 'AP0.5 (Perfect)': None, 'AP0.7 (Noisy)': None, 'AP0.7 (Perfect)': None, 'AP50': None, 'AP50(T<90)': None, 'AP50_L': None, 'AP50l': None, 'AP50m': None, 'AP50s': None, 'AP75': None, 'AP75_L': None, 'AP85': None, 'AP90(T<90)': None, 'AP@0.7': None, 'AP@0.7@CulverCity': None, 'AP@0.7@Default': None, 'AP@50': None, 'AP@75': None, 'AP@L': None, 'AP@M': None, 'AP@S': None, 'APH/L2': None, 'APL': None, 'APM': None, 'APM50': None, 'APM75': None, 'APS': None, 'APc': None, 'APf': None, 'APho': None, 'APm': None, 'APmo': None, 'APr': None, 'APs': None, 'APso': None, 'APt': None, 'APvt': None, 'AR': None, 'AR(l)': None, 'AR(m)': None, 'AR(s)': None, 'AR1': None, 'AR10': None, 'AR10_L': None, 'AR1_L': None, 'AR50': None, 'ARI': None, 'ARI-FG': None, 'ARm': None, 'ARs': None, 'ASL mAP': None, 'ASR-BLEU (Dev)': None, 'ASR-BLEU (Test)': None, 'ATV': None, ' ...
#          {'code_links': array([{'title': 'csbhr/CDVD-TSP', 'url': 'https://github.com/csbhr/CDVD-TSP'}],
#                dtype=object), 'metrics': {'\t ACCURACY': None, ' Content Ordering': None, ' Content Selection (F1)': None, ' Human listening average results': None, ' KIN': None, ' LUO': None, ' Macro-F1': None, ' Over': None, ' Rank-1': None, ' Rank-1 (All Search)': None, ' Rank-1 (Indoor Search)': None, ' Rank-5': None, ' Runtime (s)': None, ' SSIM': None, ' box AP': None, ' mAP': None, ' mAP (All Search)': None, ' mAP (Indoor Search)': None, ' mINP': None, ' mINP (All Search)': None, ' mINP (Indoor Search)': None, '# M Params': None, '# Parameters': None, '% < 11.25': None, '% < 22.5': None, '% < 30': None, '% Dev Accuracy': None, '% Test Accuracy': None, '% Test Accuracy (Raw Data)': None, '% Train Accuracy': None, '% info': None, '% true': None, '% true (GPT-judge)': None, '(Recall@10+Recall@50)/2': None, '(Recall@5+Recall_subset@1)/2': None, '-1': None, '0..5sec': None, '0L': None, '0S': None, '1 - LPIPS': None, '1 in 10 R@1': None, '1 in 10 R@2': None, '1 in 10 R@5': None, '1 step MAE': None, '1-NNA-CD': None, '1-of-100 Accuracy': None, '1/2': None, '1/4': None, '10 Hops': None, '10 fold Cross validation': None, '10 steps MAE': None, '10 way 1~2 shot': None, '10 way 5~10 shot': None, '10%': None, '10-20% Mask PSNR': None, '10-keyword Speech Commands dataset': None, '10-stage average accuracy': None, '10°10 cm': None, '12 Steps MAE': None, '12 steps MAE': None, '12 steps MAPE': None, '12 steps RMSE': None, '14 gestures accuracy': None, '1:1 Accuracy': None, '1:3 Accuracy': None, '1x1 NLL': None, '2-Class Accuracy': None, '20%': None, '20-30% Mask PSNR': None, '3-class test accuracy': None, '3-fold Accuracy': None, '30%': None, '30-40% Mask PSNR': None, '3DIoU': None, '3DMOTA': None, '3DPCK': None, '4 Hops': None, '40%': None, '40-50% Mask PSNR': None, '5 Hops': None, '5 fold cross validation': None, '5 way 1~2 shot': None, '520': None, '6 Hops': None, '7 Hops': None, '8 Hops': None, '9 Hops': None, '9 steps MAE': None, '95-th Percentile Speed Measurement Error (km/h)': None, '99-th Percentile Speed Measurement Error (km/h)': None, '99.46%': None, '@cheek': None, '@forehead': None, '@mouth': None, '@nose': None, 'A-R@1': None, 'A-R@10': None, 'A-R@5': None, 'A-acc': None, 'A-mIoU': None, 'A1': None, 'A2': None, 'A3': None, 'A3DP': None, 'AAA': None, 'ABX-across': None, 'ABX-within': None, 'ACC': None, 'ACC@1-100Clients': None, 'ACCURACY': None, 'ADDS AUC': None, 'ADE': None, 'ADE (8/12) @K=5': None, 'ADE (in world coordinates)': None, 'ADE(0.5)': None, 'ADE(1.0)': None, 'ADE(1.5)': None, 'ADE-8/12': None, 'ADE-8/12 @K = 20': None, 'AED': None, 'AEPE (rate=3)': None, 'AEPE (rate=5)': None, 'AIOU': None, 'AKD': None, 'ALL': None, 'ALL (miss rate)': None, 'AMD': None, 'AMH': None, 'AMOTA': None, 'AMV': None, 'ANLI': None, 'ANLS': None, 'ANS-EM': None, 'ANS-F1': None, 'AOP': None, 'AP': None, 'AP (Detection)': None, 'AP 0.5': None, 'AP Easy': None, 'AP Hard': None, 'AP Medium': None, 'AP novel-LVIS base training': None, 'AP novel-Unrestricted open-vocabulary training': None, 'AP(S1)': None, 'AP(S2)': None, 'AP(l)': None, 'AP(m)': None, 'AP(s)': None, 'AP/L2': None, 'AP0.5 (Noisy)': None, 'AP0.5 (Perfect)': None, 'AP0.7 (Noisy)': None, 'AP0.7 (Perfect)': None, 'AP50': None, 'AP50(T<90)': None, 'AP50_L': None, 'AP50l': None, 'AP50m': None, 'AP50s': None, 'AP75': None, 'AP75_L': None, 'AP85': None, 'AP90(T<90)': None, 'AP@0.7': None, 'AP@0.7@CulverCity': None, 'AP@0.7@Default': None, 'AP@50': None, 'AP@75': None, 'AP@L': None, 'AP@M': None, 'AP@S': None, 'APH/L2': None, 'APL': None, 'APM': None, 'APM50': None, 'APM75': None, 'APS': None, 'APc': None, 'APf': None, 'APho': None, 'APm': None, 'APmo': None, 'APr': None, 'APs': None, 'APso': None, 'APt': None, 'APvt': None, 'AR': None, 'AR(l)': None, 'AR(m)': None, 'AR(s)': None, 'AR1': None, 'AR10': None, 'AR10_L': None, 'AR1_L': None, 'AR50': None, 'ARI': None, 'ARI-FG': None, 'ARm': None, 'ARs': None, 'ASL mAP': None, 'ASR-BLEU (Dev)': None, 'ASR-BLEU (Test)': None, 'ATV': None, ' ...
#          {'code_links': array([{'title': 'sczhou/STFAN', 'url': 'https://github.com/sczhou/STFAN'}],
#                dtype=object), 'metrics': {'\t ACCURACY': None, ' Content Ordering': None, ' Content Selection (F1)': None, ' Human listening average results': None, ' KIN': None, ' LUO': None, ' Macro-F1': None, ' Over': None, ' Rank-1': None, ' Rank-1 (All Search)': None, ' Rank-1 (Indoor Search)': None, ' Rank-5': None, ' Runtime (s)': None, ' SSIM': None, ' box AP': None, ' mAP': None, ' mAP (All Search)': None, ' mAP (Indoor Search)': None, ' mINP': None, ' mINP (All Search)': None, ' mINP (Indoor Search)': None, '# M Params': None, '# Parameters': None, '% < 11.25': None, '% < 22.5': None, '% < 30': None, '% Dev Accuracy': None, '% Test Accuracy': None, '% Test Accuracy (Raw Data)': None, '% Train Accuracy': None, '% info': None, '% true': None, '% true (GPT-judge)': None, '(Recall@10+Recall@50)/2': None, '(Recall@5+Recall_subset@1)/2': None, '-1': None, '0..5sec': None, '0L': None, '0S': None, '1 - LPIPS': None, '1 in 10 R@1': None, '1 in 10 R@2': None, '1 in 10 R@5': None, '1 step MAE': None, '1-NNA-CD': None, '1-of-100 Accuracy': None, '1/2': None, '1/4': None, '10 Hops': None, '10 fold Cross validation': None, '10 steps MAE': None, '10 way 1~2 shot': None, '10 way 5~10 shot': None, '10%': None, '10-20% Mask PSNR': None, '10-keyword Speech Commands dataset': None, '10-stage average accuracy': None, '10°10 cm': None, '12 Steps MAE': None, '12 steps MAE': None, '12 steps MAPE': None, '12 steps RMSE': None, '14 gestures accuracy': None, '1:1 Accuracy': None, '1:3 Accuracy': None, '1x1 NLL': None, '2-Class Accuracy': None, '20%': None, '20-30% Mask PSNR': None, '3-class test accuracy': None, '3-fold Accuracy': None, '30%': None, '30-40% Mask PSNR': None, '3DIoU': None, '3DMOTA': None, '3DPCK': None, '4 Hops': None, '40%': None, '40-50% Mask PSNR': None, '5 Hops': None, '5 fold cross validation': None, '5 way 1~2 shot': None, '520': None, '6 Hops': None, '7 Hops': None, '8 Hops': None, '9 Hops': None, '9 steps MAE': None, '95-th Percentile Speed Measurement Error (km/h)': None, '99-th Percentile Speed Measurement Error (km/h)': None, '99.46%': None, '@cheek': None, '@forehead': None, '@mouth': None, '@nose': None, 'A-R@1': None, 'A-R@10': None, 'A-R@5': None, 'A-acc': None, 'A-mIoU': None, 'A1': None, 'A2': None, 'A3': None, 'A3DP': None, 'AAA': None, 'ABX-across': None, 'ABX-within': None, 'ACC': None, 'ACC@1-100Clients': None, 'ACCURACY': None, 'ADDS AUC': None, 'ADE': None, 'ADE (8/12) @K=5': None, 'ADE (in world coordinates)': None, 'ADE(0.5)': None, 'ADE(1.0)': None, 'ADE(1.5)': None, 'ADE-8/12': None, 'ADE-8/12 @K = 20': None, 'AED': None, 'AEPE (rate=3)': None, 'AEPE (rate=5)': None, 'AIOU': None, 'AKD': None, 'ALL': None, 'ALL (miss rate)': None, 'AMD': None, 'AMH': None, 'AMOTA': None, 'AMV': None, 'ANLI': None, 'ANLS': None, 'ANS-EM': None, 'ANS-F1': None, 'AOP': None, 'AP': None, 'AP (Detection)': None, 'AP 0.5': None, 'AP Easy': None, 'AP Hard': None, 'AP Medium': None, 'AP novel-LVIS base training': None, 'AP novel-Unrestricted open-vocabulary training': None, 'AP(S1)': None, 'AP(S2)': None, 'AP(l)': None, 'AP(m)': None, 'AP(s)': None, 'AP/L2': None, 'AP0.5 (Noisy)': None, 'AP0.5 (Perfect)': None, 'AP0.7 (Noisy)': None, 'AP0.7 (Perfect)': None, 'AP50': None, 'AP50(T<90)': None, 'AP50_L': None, 'AP50l': None, 'AP50m': None, 'AP50s': None, 'AP75': None, 'AP75_L': None, 'AP85': None, 'AP90(T<90)': None, 'AP@0.7': None, 'AP@0.7@CulverCity': None, 'AP@0.7@Default': None, 'AP@50': None, 'AP@75': None, 'AP@L': None, 'AP@M': None, 'AP@S': None, 'APH/L2': None, 'APL': None, 'APM': None, 'APM50': None, 'APM75': None, 'APS': None, 'APc': None, 'APf': None, 'APho': None, 'APm': None, 'APmo': None, 'APr': None, 'APs': None, 'APso': None, 'APt': None, 'APvt': None, 'AR': None, 'AR(l)': None, 'AR(m)': None, 'AR(s)': None, 'AR1': None, 'AR10': None, 'AR10_L': None, 'AR1_L': None, 'AR50': None, 'ARI': None, 'ARI-FG': None, 'ARm': None, 'ARs': None, 'ASL mAP': None, 'ASR-BLEU (Dev)': None, 'ASR-BLEU (Test)': None, 'ATV': None, ' ...
#         dtype=object)},
#  'subdatasets': array([], dtype=object)}

# %%
df_links_papers_code = pd.read_parquet("data/row_data/links_between_papers_and_code.parquet")
print(df_links_papers_code.columns)
# Out:
# Index(['paper_url', 'paper_title', 'paper_arxiv_id', 'paper_url_abs',
#        'paper_url_pdf', 'repo_url', 'is_official', 'mentioned_in_paper',
#        'mentioned_in_github', 'framework'],
#       dtype='object')

# %%
df_links_papers_code.iloc[0]
# Out:
# paper_url              https://paperswithcode.com/paper/automatic-pos...
# paper_title            Automatic Post-Editing of Machine Translation:...
# paper_arxiv_id                                                      None
# paper_url_abs                          https://aclanthology.org/D18-1341
# paper_url_pdf                      https://aclanthology.org/D18-1341.pdf
# repo_url                              https://github.com/trangvu/ape-npi
# is_official                                                        False
# mentioned_in_paper                                                 False
# mentioned_in_github                                                False
# framework                                                             tf
# Name: 0, dtype: object

# %%
df_methods = pd.read_parquet("data/row_data/methods.parquet")
print(df_methods.columns)
# Out:
# Index(['url', 'name', 'full_name', 'description', 'paper', 'introduced_year',
#        'source_url', 'source_title', 'code_snippet_url', 'num_papers',
#        'collections'],
#       dtype='object')

# %%
df_methods.iloc[0]
# Out:
# url                            https://paperswithcode.com/method/rife
# name                                                             RIFE
# full_name                                                        RIFE
# description         **RIFE**, or **Real-time Intermediate Flow Est...
# paper               {'title': 'RIFE: Real-Time Intermediate Flow E...
# introduced_year                                                  2000
# source_url                        https://arxiv.org/abs/2011.06294v11
# source_title        RIFE: Real-Time Intermediate Flow Estimation f...
# code_snippet_url
# num_papers                                                          2
# collections         [{'area': 'Computer Vision', 'area_id': 'compu...
# Name: 0, dtype: object

# %%
df_papers_abs = pd.read_parquet("data/row_data/papers_with_abstracts.parquet")
print(df_papers_abs.columns)
# Out:
# Index(['paper_url', 'arxiv_id', 'title', 'abstract', 'url_abs', 'url_pdf',
#        'proceeding', 'authors', 'tasks', 'date', 'methods'],
#       dtype='object')

# %%
df_papers_abs.iloc[8]
# Out:
# paper_url     https://paperswithcode.com/paper/deep-spatiote...
# arxiv_id                                             1806.06793
# title         Deep Spatiotemporal Representation of the Face...
# abstract      Automatic pain intensity assessment has a high...
# url_abs                       http://arxiv.org/abs/1806.06793v1
# url_pdf                   http://arxiv.org/pdf/1806.06793v1.pdf
# proceeding                                                 None
# authors                   [Mohammad Tavakolian, Abdenour Hadid]
# tasks                                                        []
# date                                                 2018-06-18
# methods       [{'code_snippet_url': 'https://github.com/pyto...
# Name: 8, dtype: object

# %%
df_papers_abs[df_papers_abs["tasks"].apply(lambda k:len(k)) > 1]
# Out:
#                                                 paper_url    arxiv_id  \
# 6       https://paperswithcode.com/paper/scaling-neura...  1806.00187
# 11      https://paperswithcode.com/paper/bingan-learni...  1806.06778
# 14      https://paperswithcode.com/paper/kid-net-convo...  1806.06769
# 15      https://paperswithcode.com/paper/modularity-ma...  1806.06765
# 18      https://paperswithcode.com/paper/pots-protecti...  1806.02711
# ...                                                   ...         ...
# 354828  https://paperswithcode.com/paper/robust-divers...        None
# 354830  https://paperswithcode.com/paper/learning-bett...        None
# 354831  https://paperswithcode.com/paper/contrastive-r...        None
# 354833  https://paperswithcode.com/paper/multi-object-...        None
# 354834  https://paperswithcode.com/paper/ridcp-revital...        None
#
#                                                     title  \
# 6                      Scaling Neural Machine Translation
# 11      BinGAN: Learning Compact Binary Descriptors wi...
# 14      Kid-Net: Convolution Networks for Kidney Vesse...
# 15      Modularity Matters: Learning Invariant Relatio...
# 18             POTs: Protective Optimization Technologies
# ...                                                   ...
# 354828  Robust Diversified Graph Contrastive Network f...
# 354830  Learning Better Registration to Learn Better F...
# 354831  Contrastive Re-localization and History Distil...
# 354833  Multi-object Tracking: Decoupling Features to ...
# 354834  RIDCP: Revitalizing Real Image Dehazing via Hi...
#
#                                                  abstract  \
# 6       Sequence to sequence learning models still req...
# 11      In this paper, we propose a novel regularizati...
# 14      Semantic image segmentation plays an important...
# 15      We focus on two supervised visual reasoning ta...
# 18      Algorithmic fairness aims to address the econo...
# ...                                                   ...
# 354828  Incomplete multi-view clustering is a challeng...
# 354830  In this work, we address the task of few-shot ...
# 354831  Federated learning (FL) has shown value in mul...
# 354833  Multi-object tracking achieves the acquisition...
# 354834  Existing dehazing approaches struggle to proce...
#
#                                                   url_abs  \
# 6                       http://arxiv.org/abs/1806.00187v3
# 11                      http://arxiv.org/abs/1806.06778v5
# 14                      http://arxiv.org/abs/1806.06769v1
# 15                      http://arxiv.org/abs/1806.06765v1
# 18                     https://arxiv.org/abs/1806.02711v6
# ...                                                   ...
# 354828  https://dl.acm.org/doi/abs/10.1145/3503161.354...
# 354830  https://ieeexplore.ieee.org/abstract/document/...
# 354831  https://link.springer.com/chapter/10.1007/978-...
# 354833      https://ieeexplore.ieee.org/document/10053999
# 354834  https://rq-wu.github.io/projects/RIDCP/index.html
#
#                                                   url_pdf  \
# 6                   http://arxiv.org/pdf/1806.00187v3.pdf
# 11                  http://arxiv.org/pdf/1806.06778v5.pdf
# 14                  http://arxiv.org/pdf/1806.06769v1.pdf
# 15                  http://arxiv.org/pdf/1806.06765v1.pdf
# 18                 https://arxiv.org/pdf/1806.02711v6.pdf
# ...                                                   ...
# 354828  https://dl.acm.org/doi/pdf/10.1145/3503161.354...
# 354830  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 354831  https://www.researchgate.net/publication/36357...
# 354833  https://ieeexplore.ieee.org/stamp/stamp.jsp?tp...
# 354834  https://github.com/RQ-Wu/RIDCP_dehazing/blob/m...
#
#                                                proceeding  \
# 6                                              WS 2018 10
# 11                                        NeurIPS 2018 12
# 14                                                   None
# 15                                                   None
# 18                                                   None
# ...                                                   ...
# 354828  ACM International Conference on Multimedia 202...
# 354830  IEEE Transactions on Neural Networks and Learn...
# 354831                                 MICCAI 2022 2022 9
# 354833  IEEE Transactions on Circuits and Systems for ...
# 354834  Proceedings of the IEEE/CVF Conference on Comp...
#
#                                                   authors  \
# 6       [Myle Ott, Sergey Edunov, David Grangier, Mich...
# 11      [Maciej Zieba, Piotr Semberecki, Tarek El-Gaal...
# 14          [Ahmed Taha, Pechin Lo, Junning Li, Tao Zhao]
# 15                 [Jason Jo, Vikas Verma, Yoshua Bengio]
# 18      [Bogdan Kulynych, Rebekah Overdorf, Carmela Tr...
# ...                                                   ...
# 354828  [Zhe Xue, Junping Du, Hai Zhu, Zhongchao Guan,...
# 354830  [Yuting He; Rongjun Ge; Xiaoming Qi; Yang Chen...
# 354831  [Xiaoming Qi, Guanyu Yang, Yuting He, Wangyan ...
# 354833  [Yan Jin; Fang Gao; Jun Yu; Jiabao Wang; Feng ...
# 354834  [Ruiqi Wu, Zhengpeng Duan, Chunle Guo, Zhi Cha...
#
#                                                     tasks        date  \
# 6       [Machine Translation, Question Answering, Tran...  2018-06-01
# 11                  [Dimensionality Reduction, Retrieval]  2018-06-18
# 14      [Anatomy, Image Segmentation, Semantic Segment...  2018-06-18
# 15               [Relational Reasoning, Visual Reasoning]  2018-06-18
# 18                            [Decision Making, Fairness]  2018-06-07
# ...                                                   ...         ...
# 354828  [Contrastive Learning, Incomplete multi-view c...  2022-10-10
# 354830  [Image Segmentation, Medical Image Segmentatio...  2022-07-22
# 354831  [Federated Learning, Image Segmentation, Medic...  2022-09-16
# 354833  [Association, Multi-Object Tracking, Object Tr...  2023-02-27
# 354834            [Image Dehazing, Single Image Dehazing]  2023-02-28
#
#                                                   methods
# 6                                                      []
# 11                                                     []
# 14      [{'code_snippet_url': None, 'description': 'A ...
# 15      [{'code_snippet_url': '', 'description': '**Av...
# 18                                                     []
# ...                                                   ...
# 354828  [{'code_snippet_url': None, 'description': '',...
# 354830                                                 []
# 354831                                                 []
# 354833  [{'code_snippet_url': 'https://github.com/lore...
# 354834                                                 []
#
# [144748 rows x 11 columns]
